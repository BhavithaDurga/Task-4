# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading File

# %%
car_sales = pd.read_csv("Car_sales.csv")

# %%
car_sales.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639

# %%
#getting the shape of the dataframe
car_sales.shape
# Out:
# (157, 16)

# %%
# names of the columns 
car_sales.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
#basic statistics 
car_sales.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# 25%       2.300000  149.500000  103.000000   68.400000  177.575000
# 50%       3.000000  177.500000  107.000000   70.550000  187.900000
# 75%       3.575000  215.000000  112.200000   73.425000  196.125000
# max       8.000000  450.000000  138.700000   79.900000  224.500000
#
#        Curb_weight  Fuel_capacity  Fuel_efficiency  Power_perf_factor
# count   155.000000     156.000000       154.000000         155.000000
# mean      3.378026      17.951923        23.844156          77.043591
# std       0.630502       3.887921         4.282706          25.142664
# min       1.895000      10.300000        15.000000          23.276272
# 25%       2.971000      15.800000        21.000000          60.407707
# 50%       3.342000      17.200000        24.000000          72.030917
# 75%       3.799500      19.575000        26.000000          89.414878
# max       5.572000      32.000000        45.000000         188.144323

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
#  15  Power_perf_factor    155 non-null    float64
# dtypes: float64(12), object(4)
# memory usage: 19.8+ KB

# %%
# getting different types of vehicle types
car_sales['Vehicle_type'].unique()
# Out:
# array(['Passenger', 'Car'], dtype=object)

# %%
#getting unique values of Manufactures
car_sales['Manufacturer'].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'Honda', 'Hyundai', 'Infiniti',
#        'Jaguar', 'Jeep', 'Lexus', 'Lincoln', 'Mitsubishi', 'Mercury',
#        'Mercedes-B', 'Nissan', 'Oldsmobile', 'Plymouth', 'Pontiac',
#        'Porsche', 'Saab', 'Saturn', 'Subaru', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %% [markdown]
# ### # There are 2 type of vehicle type first we try to learn that how our sales depend on the ' vehicle type'

# %%
# 'Vehicle_type' is a categorical variable which has two values -- 'Passenger' and 'Car'

sns.set(style="ticks", color_codes=True)

# %% [markdown]
# Statistical analysis is a process of understanding how variables in a dataset relate to each other and how those relationships depend on other variables. Visualization can be a core component of this process because, when data are visualized properly, the human visual system can see trends and patterns that indicate a relationship.

# %%
sns.catplot(x="Vehicle_type", y="Sales_in_thousands", data=car_sales);

# %%
sns.catplot(x='Vehicle_type',y='Sales_in_thousands',jitter=False,data=car_sales)

# %% [markdown]
#  It can give a better representation of the distribution of observations, although it only works well for relatively small datasets. This kind of plot is sometimes called a “beeswarm” and is drawn in seaborn by swarmplot(), which is activated by setting ```kind="swarm" in catplot()```

# %%
sns.catplot(x='Vehicle_type',y='Sales_in_thousands',kind='swarm',data=car_sales)

# %%
#get the count of rows for each type of vehicle type
car_sales.groupby('Vehicle_type').count()
# Out:
#               Manufacturer  Model  Sales_in_thousands  __year_resale_value  \
# Vehicle_type
# Car                     41     41                  41                   30
# Passenger              116    116                 116                   91
#
#               Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  \
# Vehicle_type
# Car                           40           40          40         40     40
# Passenger                    115          116         116        116    116
#
#               Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# Vehicle_type
# Car               40           40             40               40
# Passenger        116          115            116              114
#
#               Latest_Launch  Power_perf_factor
# Vehicle_type
# Car                      41                 40
# Passenger               116                115

# %% [markdown]
# #### We can se that most of the Vehicles are of type 'Passenger'

# %%
rs = car_sales.groupby('Manufacturer')['Manufacturer','Sales_in_thousands']

# %%
sns.catplot(x="Manufacturer", y="Sales_in_thousands", data=car_sales.head(20));

# %% [markdown]
# #### Below I am practising pandas library
# Pandas library is very helpful in ``analyising, manipulating data``

# %%
grouped = car_sales.groupby('Manufacturer')

# %%
for group, df in grouped:
    #print(group,'\n')
    print(df[['Manufacturer','Model','Sales_in_thousands']],'\n')
# Out:
#   Manufacturer    Model  Sales_in_thousands
# 0        Acura  Integra              16.919
# 1        Acura       TL              39.384
# 2        Acura       CL              14.114
# 3        Acura       RL               8.588
#
#   Manufacturer Model  Sales_in_thousands
# 4         Audi    A4              20.397
# 5         Audi    A6              18.780
# 6         Audi    A8               1.380
#
#   Manufacturer Model  Sales_in_thousands
# 7          BMW  323i              19.747
# 8          BMW  328i               9.231
# 9          BMW  528i              17.527
#
#    Manufacturer        Model  Sales_in_thousands
# 10        Buick      Century              91.561
# 11        Buick        Regal              39.350
# 12        Buick  Park Avenue              27.851
# 13        Buick      LeSabre              83.257
#
#    Manufacturer     Model  Sales_in_thousands
# 14     Cadillac   DeVille              63.729
# 15     Cadillac   Seville              15.943
# 16     Cadillac  Eldorado               6.536
# 17     Cadillac    Catera              11.185
# 18     Cadillac  Escalade              14.785
#
#    Manufacturer        Model  Sales_in_thousands
# 19    Chevrolet     Cavalier             145.519
# 20    Chevrolet       Malibu             135.126
# 21    Chevrolet       Lumina              24.629
# 22    Chevrolet  Monte Carlo              42.593
# 23    Chevrolet       Camaro              26.402
# 24    Chevrolet     Corvette              17.947
# 25    Chevrolet        Prizm              32.299
# 26    Chevrolet        Metro              21.855
# 27    Chevrolet       Impala             107.995
#
#    Manufacturer           Model  Sales_in_thousands
# 28     Chrysler   Sebring Coupe               7.854
# 29     Chrysler   Sebring Conv.              32.775
# 30     Chrysler        Concorde              31.148
# 31     Chrysler          Cirrus              32.306
# 32     Chrysler             LHS              13.462
# 33     Chrysler  Town & Country              53.480
# 34     Chrysler            300M              30.696
#
#    Manufacturer       Model  Sales_in_thousands
# 35        Dodge        Neon              76.034
# 36        Dodge     Avenger               4.734
# 37        Dodge     Stratus              71.186
# 38        Dodge    Intrepid              88.028
# 39        Dodge       Viper               0.916
# 40        Dodge  Ram Pickup             227.061
# 41        Dodge   Ram Wagon              16.767
# 42        Dodge     Ram Van              31.038
# 43        Dodge      Dakota             111.313
# 44        Dodge     Durango             101.323
# 45        Dodge     Caravan             181.749
#
#    Manufacturer           Model  Sales_in_thousands
# 46         Ford          Escort              70.227
# 47         Ford         Mustang             113.369
# 48         Ford         Contour              35.068
# 49         Ford          Taurus             245.815
# 50         Ford           Focus             175.670
# 51         Ford  Crown Victoria              63.403
# 52         Ford        Explorer             276.747
# 53         Ford        Windstar             155.787
# 54         Ford      Expedition             125.338
# 55         Ford          Ranger             220.650
# 56         Ford        F-Series             540.561
#
#    Manufacturer     Model  Sales_in_thousands
# 57        Honda     Civic             199.685
# 58        Honda    Accord             230.902
# 59        Honda      CR-V              73.203
# 60        Honda  Passport              12.855
# 61        Honda   Odyssey              76.029
#
#    Manufacturer    Model  Sales_in_thousands
# 62      Hyundai   Accent              41.184
# 63      Hyundai  Elantra              66.692
# 64      Hyundai   Sonata              29.450
#
#    Manufacturer Model  Sales_in_thousands
# 65     Infiniti   I30              23.713
#
#    Manufacturer   Model  Sales_in_thousands
# 66       Jaguar  S-Type              15.467
#
#    Manufacturer           Model  Sales_in_thousands
# 67         Jeep        Wrangler              55.557
# 68         Jeep        Cherokee              80.556
# 69         Jeep  Grand Cherokee             157.040
#
#    Manufacturer  Model  Sales_in_thousands
# 70        Lexus  ES300              24.072
# 71        Lexus  GS300              12.698
# 72        Lexus  GS400               3.334
# 73        Lexus  LS400               6.375
# 74        Lexus  LX470               9.126
# 75        Lexus  RX300              51.238
#
#    Manufacturer        Model  Sales_in_thousands
# 76      Lincoln  Continental              13.798
# 77      Lincoln     Town car              48.911
# 78      Lincoln    Navigator              22.925
#
#     Manufacturer      Model  Sales_in_thousands
# 92    Mercedes-B    C-Class              18.392
# 93    Mercedes-B    E-Class              27.602
# 94    Mercedes-B    S-Class              16.774
# 95    Mercedes-B   SL-Class               3.311
# 96    Mercedes-B        SLK               7.998
# 97    Mercedes-B     SLK230               1.526
# 98    Mercedes-B  CLK Coupe              11.592
# 99    Mercedes-B      CL500               0.954
# 100   Mercedes-B    M-Class              28.976
#
#    Manufacturer          Model  Sales_in_thousands
# 86      Mercury       Mystique              14.351
# 87      Mercury         Cougar              26.529
# 88      Mercury          Sable              67.956
# 89      Mercury  Grand Marquis              81.174
# 90      Mercury    Mountaineer              27.609
# 91      Mercury       Villager              20.380
#
#    Manufacturer          Model  Sales_in_thousands
# 79   Mitsubishi         Mirage              26.232
# 80   Mitsubishi        Eclipse              42.541
# 81   Mitsubishi         Galant              55.616
# 82   Mitsubishi       Diamante               5.711
# 83   Mitsubishi         3000GT               0.110
# 84   Mitsubishi        Montero              11.337
# 85   Mitsubishi  Montero Sport              39.348
#
#     Manufacturer       Model  Sales_in_thousands
# 101       Nissan      Sentra              42.643
# 102       Nissan      Altima              88.094
# 103       Nissan      Maxima              79.853
# 104       Nissan       Quest              27.308
# 105       Nissan  Pathfinder              42.574
# 106       Nissan      Xterra              54.158
# 107       Nissan    Frontier              65.005
#
#     Manufacturer       Model  Sales_in_thousands
# 108   Oldsmobile     Cutlass               1.112
# 109   Oldsmobile    Intrigue              38.554
# 110   Oldsmobile       Alero              80.255
# 111   Oldsmobile      Aurora              14.690
# 112   Oldsmobile     Bravada              20.017
# 113   Oldsmobile  Silhouette              24.361
#
#     Manufacturer    Model  Sales_in_thousands
# 114     Plymouth     Neon              32.734
# 115     Plymouth   Breeze               5.240
# 116     Plymouth  Voyager              24.155
# 117     Plymouth  Prowler               1.872
#
#     Manufacturer       Model  Sales_in_thousands
# 118      Pontiac     Sunfire              51.645
# 119      Pontiac    Grand Am             131.097
# 120      Pontiac    Firebird              19.911
# 121      Pontiac  Grand Prix              92.364
# 122      Pontiac  Bonneville              35.945
# 123      Pontiac     Montana              39.572
#
#     Manufacturer           Model  Sales_in_thousands
# 124      Porsche          Boxter               8.982
# 125      Porsche   Carrera Coupe               1.280
# 126      Porsche  Carrera Cabrio               1.866
#
#     Manufacturer  Model  Sales_in_thousands
# 127         Saab  5-Sep               9.191
# 128         Saab  3-Sep              12.115
#
#     Manufacturer Model  Sales_in_thousands
# 129       Saturn    SL              80.620
# 130       Saturn    SC              24.546
# 131       Saturn    SW               5.223
# 132       Saturn    LW               8.472
# 133       Saturn    LS              49.989
#
#     Manufacturer     Model  Sales_in_thousands
# 134       Subaru   Outback              47.107
# 135       Subaru  Forester              33.028
#
#     Manufacturer         Model  Sales_in_thousands
# 136       Toyota       Corolla             142.535
# 137       Toyota         Camry             247.994
# 138       Toyota        Avalon              63.849
# 139       Toyota        Celica              33.269
# 140       Toyota        Tacoma              84.087
# 141       Toyota        Sienna              65.119
# 142       Toyota          RAV4              25.106
# 143       Toyota       4Runner              68.411
# 144       Toyota  Land Cruiser               9.835
#
#     Manufacturer   Model  Sales_in_thousands
# 145   Volkswagen    Golf               9.761
# 146   Volkswagen   Jetta              83.721
# 147   Volkswagen  Passat              51.102
# 148   Volkswagen  Cabrio               9.569
# 149   Volkswagen     GTI               5.596
# 150   Volkswagen  Beetle              49.463
#
#     Manufacturer Model  Sales_in_thousands
# 151        Volvo   S40              16.957
# 152        Volvo   V40               3.545
# 153        Volvo   S70              15.245
# 154        Volvo   V70              17.531
# 155        Volvo   C70               3.493
# 156        Volvo   S80              18.969

# %%
# for selecting specific columns from a dataframe
car_sales[['Manufacturer','Model','Sales_in_thousands']].head(20)
# Out:
#    Manufacturer        Model  Sales_in_thousands
# 0         Acura      Integra              16.919
# 1         Acura           TL              39.384
# 2         Acura           CL              14.114
# 3         Acura           RL               8.588
# 4          Audi           A4              20.397
# 5          Audi           A6              18.780
# 6          Audi           A8               1.380
# 7           BMW         323i              19.747
# 8           BMW         328i               9.231
# 9           BMW         528i              17.527
# 10        Buick      Century              91.561
# 11        Buick        Regal              39.350
# 12        Buick  Park Avenue              27.851
# 13        Buick      LeSabre              83.257
# 14     Cadillac      DeVille              63.729
# 15     Cadillac      Seville              15.943
# 16     Cadillac     Eldorado               6.536
# 17     Cadillac       Catera              11.185
# 18     Cadillac     Escalade              14.785
# 19    Chevrolet     Cavalier             145.519

# %% [markdown]
# The most basic, which should be used ``when both variables are numeric, is the scatterplot() function``
# scatterplot() info -- https://seaborn.pydata.org/tutorial/relational.html#relating-variables-with-scatter-plots

# %%
sns.set(style='darkgrid')

# %%
car_sales.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
car_sales.head(5)
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
#    Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# 0        2.639           13.2             28.0      2/2/2012
# 1        3.517           17.2             25.0      6/3/2011
# 2        3.470           17.2             26.0      1/4/2012
# 3        3.850           18.0             22.0     3/10/2011
# 4        2.998           16.4             27.0     10/8/2011
#
#    Power_perf_factor
# 0          58.280150
# 1          91.370778
# 2                NaN
# 3          91.389779
# 4          62.777639

# %%
car_sales[['Model','Sales_in_thousands','Price_in_thousands','Engine_size','Horsepower','Width','Length','Fuel_efficiency']].head()
# Out:
#      Model  Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  \
# 0  Integra              16.919               21.50          1.8       140.0
# 1       TL              39.384               28.40          3.2       225.0
# 2       CL              14.114                 NaN          3.2       225.0
# 3       RL               8.588               42.00          3.5       210.0
# 4       A4              20.397               23.99          1.8       150.0
#
#    Width  Length  Fuel_efficiency
# 0   67.3   172.4             28.0
# 1   70.3   192.9             25.0
# 2   70.6   192.0             26.0
# 3   71.4   196.6             22.0
# 4   68.2   178.0             27.0

# %%
#seeing that relation between price and sales of car
sns.relplot(x='Price_in_thousands',y='Sales_in_thousands',data = car_sales)

# %%
#plotting three variables with the scatterplot the third axis is hue
sns.relplot(x='Price_in_thousands', y='Sales_in_thousands',hue='Manufacturer',data=car_sales)


# we can infer from the below graph most of the cars are in price range 50k and have sales upto 100k

# %%
car_sales.columns
# Out:
# Index(['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value',
#        'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower',
#        'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity',
#        'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor'],
#       dtype='object')

# %%
# seeing the statistics of parameter 'Engine_size'
car_sales.Engine_size.describe()
# Out:
# count    156.000000
# mean       3.060897
# std        1.044653
# min        1.000000
# 25%        2.300000
# 50%        3.000000
# 75%        3.575000
# max        8.000000
# Name: Engine_size, dtype: float64

# %%
#car_sales.Engine_size.unique()
sns.relplot(y='Price_in_thousands',x='Engine_size',data=car_sales)

# %%
sns.relplot(y='Sales_in_thousands',x='Engine_size',data=car_sales)

# %%
sns.relplot(x='Engine_size',y='Sales_in_thousands',kind='line',data=car_sales)

# %%
sns.relplot(x='Price_in_thousands',y='Sales_in_thousands',kind='line',data=car_sales)

# %%
sns.relplot(x='Horsepower',y='Sales_in_thousands',kind='scatter',data=car_sales)

# %%
sns.pairplot(data=car_sales,x_vars=['Price_in_thousands','Engine_size','Horsepower','Wheelbase', 'Width', 'Length','Fuel_capacity',
       'Fuel_efficiency'],y_vars=['Sales_in_thousands'])
